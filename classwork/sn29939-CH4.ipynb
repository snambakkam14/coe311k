# %%
import numpy as np

# %%
def leib_series (n):
    
    value = 4*(((-1)**n)/(2n+1))

# %%
for i in range (0,5000):
    counter = 1
    sum = 0
    for j in range (0,i):
        sum += leib_series(n)
