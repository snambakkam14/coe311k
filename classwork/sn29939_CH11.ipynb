# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# Define known data points
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])
# Create a cubic spline interpolation of the data
cs = CubicSpline(x, y, bc_type='natural')
# Generate new x values for a smooth plot
x_smooth = np.linspace(0, 5, 100)
y_cs = cs(x_interp)

cfs = np.polyfit(x,y,3)
poly_func = np.poly1d(cfs)


y_pf = poly_func(x_smooth)


plt.plot(x, y, 'bo', label="Data points")
plt.plot(x_smooth, y_cs, 'g-', label="Cubic Spline")
plt.plot(x_smooth,y_pf,'b-', label = "Polynomial Fitting")
plt.title("Cubic Spline Interpolation vs Polynomial Fitting")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# The Polynomial fit doesn't fit the data nearly as well as the Cubic Spline interpolation does as the Polynomial fit tries to approximate the data as a cubic function, leaving a good bit of residual between the data point and the predicted data point. On the other hand, the Cubic Spline interpolation results in a function which take a sinusoidal form, representing the data very well.
