# %%
import numpy as np
import matplotlib.pyplot as plt
import time as tm

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
            
        x = x_new
        
    return x, max_iterations

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()

    for k in range(max_iterations):
        x_new = x.copy()

        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (b[i] - s1 - s2) / A[i][i]

        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k

        x = x_new

    return x, max_iterations

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)


x0 = np.zeros_like(b)

tol = 1e-6

max_iterations = 100


#jacobi


start_time = tm.time()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time - start_time} seconds")



#gauss seidel



start_time = tm.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"SOLUTION: {solution}")
print(f"ITERATIONS: {iterations}")
print(f"TIME: {end_time - start_time} seconds")
# Out:
# Solution: [0.34253948 0.34219824 0.34215212 0.34233398 0.34277892]
# Iterations: 100
# Time: 0.006673574447631836 seconds
# SOLUTION: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# ITERATIONS: 20
# TIME: 0.0015015602111816406 seconds

# %%
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1])

x0 = np.zeros_like(b)

tol = 1e-6

max_iterations = 100


#jacobi


start_time = tm.time()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time - start_time} seconds")



#gauss seidel



start_time = tm.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"SOLUTION: {solution}")
print(f"ITERATIONS: {iterations}")
print(f"TIME: {end_time - start_time} seconds")
# Out:
# Solution: [1 0]
# Iterations: 1
# Time: 0.001306295394897461 seconds
# SOLUTION: [1 0]
# ITERATIONS: 1
# TIME: 0.00042510032653808594 seconds

# %%
A = np.array([[1, 	1], [1, 1.0001]])
b = np.array([1, 1.0001])

x0 = np.zeros_like(b, dtype = 'float')

tol = 1e-6

max_iterations = 100


#jacobi


start_time = tm.time()

solution, iterations = jacobi(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"Solution: {solution}")
print(f"Iterations: {iterations}")
print(f"Time: {end_time - start_time} seconds")



#gauss seidel



start_time = tm.time()

solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)

end_time = tm.time()


print(f"SOLUTION: {solution}")
print(f"ITERATIONS: {iterations}")
print(f"TIME: {end_time - start_time} seconds")
# Out:
# Solution: [0.         0.00498727]
# Iterations: 100
# Time: 0.0039751529693603516 seconds
# SOLUTION: [0.99014933 0.00994967]
# ITERATIONS: 100
# TIME: 0.0038537979125976562 seconds

# %%
A = np.array([
	[0.582745, 0.48	, 0.10	, 0.  	, 0.  	], 
 [0.48	, 1.044129, 0.46	, 0.10	, 0.  	],
 [0.10	, 0.46	, 1.10431 , 0.44	, 0.10	],
 [0.  	, 0.10	, 0.44	, 0.963889, 0.42	],
 [0.  	, 0.  	, 0.10	, 0.42	, 0.522565]], dtype=float)

def diagonally_dominant(A):
    total = 0
    a2 = 0
    for i in range (0,len(A)):
        a1 = A[i][i]
        a2 = 0
        for j in range (0,len(A)):
            if i != j:
                a2 += A[i][j]
        if (np.abs(a1)<np.abs(a2)):
            return A, False
    return A, True

# %%
diagonally_dominant(A)
# Out:
# (array([[0.582745, 0.48    , 0.1     , 0.      , 0.      ],
#         [0.48    , 1.044129, 0.46    , 0.1     , 0.      ],
#         [0.1     , 0.46    , 1.10431 , 0.44    , 0.1     ],
#         [0.      , 0.1     , 0.44    , 0.963889, 0.42    ],
#         [0.      , 0.      , 0.1     , 0.42    , 0.522565]]), True)
