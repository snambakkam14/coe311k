# %%
import random
import math
import numpy as np
import matplotlib.pyplot as plt

def pi_approx(samples):
    counter = 0
    for x in range(0,samples):
        a = random.uniform(-1,1)
        b = random.uniform(-1,1)
        if (a**2 + b**2 < 1):
            counter = counter + 1
    num = counter/samples
    approx = num * 4
    return approx
# Out:
# 3.144

# %%
error = []

for i in range(10,1000,20):
    mc_sim = pi_approx(i)
    err = np.abs(np.pi - mc_sim)
    error.append(err)
    print(f"Samples={i}, Error={err:.15f}")
# Out:
# Samples=10, Error=0.341592653589793
# Samples=30, Error=0.325074013076874
# Samples=50, Error=0.421592653589793
# Samples=70, Error=0.058407346410207
# Samples=90, Error=0.013962901965762
# Samples=110, Error=0.087047199044338
# Samples=130, Error=0.033900345897485
# Samples=150, Error=0.298407346410207
# Samples=170, Error=0.012180888883911
# Samples=190, Error=0.215276864116109
# Samples=210, Error=0.020312108314969
# Samples=230, Error=0.075798650758033
# Samples=250, Error=0.005592653589793
# Samples=270, Error=0.163814875812015
# Samples=290, Error=0.134696101865655
# Samples=310, Error=0.006794443184400
# Samples=330, Error=0.208259320256460
# Samples=350, Error=0.044449796446936
# Samples=370, Error=0.155704643707504
# Samples=390, Error=0.044156756153896
# Samples=410, Error=0.068163443971183
# Samples=430, Error=0.011895718503230
# Samples=450, Error=0.040629568632429
# Samples=470, Error=0.058407346410207
# Samples=490, Error=0.096694694406120
# ...

# %%
samp = np.arange(10,1000,20)

plt.figure()
plt.
plt.scatter(samp,error)
